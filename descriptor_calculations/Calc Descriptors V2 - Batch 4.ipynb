# %%
import psi4
from rdkit import Chem
from rdkit.Chem import AllChem
import numpy as np
import pandas as pd
from rdkit.Chem import Descriptors
from rdkit.Chem.rdMolDescriptors import CalcMolFormula

# %% [markdown]
# # Import CSV file containing fuels

# %%
df= pd.read_csv('FuelList2.csv')
df
# Out:
#      ID                    Fuel  Boiling Point (K)
# 0   103                 Methane            111.650
# 1   104                Triptane            353.950
# 2   105     2,2-Dimethylpropane            282.650
# 3   106      2,2-Dimethylbutane            322.850
# 4   107         Vinylacetylene             278.250
# 5   108         Methylacetylene            249.950
# 6   109           1,3-Butadiene            268.750
# 7   110               1-Heptyne            372.850
# 8   111               2-Pentene            309.883
# 9   112           Diisobutylene            374.350
# 10  113                Methanol            337.850
# 11  114    Isopropyl mercaptan             325.650
# 12  115      Isopropyl alcohol             183.650
# 13  116         Allyl chloride             318.250
# 14  117      n-Propyl chloride             319.650
# 15  118     Isopropyl chloride             308.850
# 16  119         Isopropylamine             304.850
# 17  120        Propionaldehyde             321.150
# 18  121          Vinyl acetate             345.650
# 19  122       Dimethoxymethane             315.150
# 20  123       Dimethyl sulfide             310.450
# 21  124  Di-tert-butyl peroxide            384.150
# 22  125                  Furan             304.650
# 23  126               Thiophene            357.150
# 24  127          Ethylene oxide            283.750
# 25  128           Dihydropyran             359.150
# 26  129           Ethylenimine             329.150
# 27  130        Tetrahydrofuran             338.150
# 28  131         Cyclopentadiene            314.150
# 29  132         Tetrahydropyran            361.150
# 30  133        Carbon disulfide            319.150
# 31  134       Hydrogen sulfide             212.820

# %% [markdown]
# # Function to query the NIH database for molecules matching the input string and then perform chemical structure identifier conversion: IUPAC to SMILES

# %%
from urllib.request import urlopen
from urllib.parse import quote
from rdkit.Chem import AllChem

#Chemical name to SMILES:

def toSmiles(ids):
    try:
        url = 'https://cactus.nci.nih.gov/chemical/structure/' + quote(ids) + '/smiles'
        ans = urlopen(url).read().decode('utf8')
        return ans
    except:
        return 'Enter a valid IUPAC name'

# %% [markdown]
# # Generate SMILES column and add it to existing dataframe

# %%
fuel_name = df['Fuel']
smiles_list = []
index = -1
for ids in fuel_name:
    index+=1
    smiles_list.append(toSmiles(ids))
    if toSmiles(ids) == 'Enter a valid IUPAC name':
        print(ids + ' failed at index ' + str(index))

# %% [markdown]
# # Define function that will optimize a molecule's 3D structure to obtain the structure with the lowest energy - Round 1
# # **Important for desriptor calculations

# %%
def optimize(m):
    """ 
        Input: RDKit molecule object
        
        Optimizes molecular structure by applying the Merck molecular force field 94(MMFF94) before performing tasks:
        
        1. Calculates total number of atoms
        
        2. Coverts geometry of mol object to a string of xyz coordinates
    
    """
    m = Chem.AddHs(m)#add hydrogens to structure
    #Convert from 2D to 3D
    AllChem.EmbedMolecule(m,randomSeed=0xf00d,useExpTorsionAnglePrefs=True,useBasicKnowledge=True)#intialize molecular conformation
    AllChem.MMFFOptimizeMolecule(m,'MMFF94')#apply force field
    atoms = m.GetAtoms()
    string = "\n"
    for i, atom in enumerate(atoms):
        pos = m.GetConformer().GetAtomPosition(atom.GetIdx())
        string += "{} {} {} {}\n".format(atom.GetSymbol(), pos.x, pos.y, pos.z)
    string += "units angstrom\n"
    string += "symmetry c1\n"
    #-------------------------------------------
    totAtoms = m.GetNumAtoms()
    #-----------------------------------------------
    
    
    return totAtoms, string, m

# %% [markdown]
# # Calculate descriptors: Number of atoms, molecular weight, IC0, PJI3, SIC0, GATS1v, Wiener Index, Zagreb Index

# %%
from mordred import InformationContent
from mordred import GeometricalIndex
from mordred import Autocorrelation
from mordred import WienerIndex
from mordred import ZagrebIndex

IC0_calc = InformationContent.InformationContent(order=0)
petitjean_calc = GeometricalIndex.PetitjeanIndex3D()
SIC0_calc = InformationContent.StructuralIC(order=0)
GATS1v_calc = Autocorrelation.GATS(order=1,prop='v')
wiener_index = WienerIndex.WienerIndex()
zagreb_index1 = ZagrebIndex.ZagrebIndex(version = 1) 



IC0_list = [] # Information content index (neighborhood symmetry of 0-order)
petitjean_3D = [] #3D petitjean shape index
SIC0_list = []
GATS1v_list = []
wiener_list= [] #stores wiener indices
Z1_list = [] #stores zagreb1 indices



MW_list = [] #stores molecular weight
mol_form = [] #stores molecular formulas
N_atoms = [] #stores number of atoms
xyzgeom_list = [] #stores xyz coordinates


for smiles in smiles_list:

    mol = Chem.MolFromSmiles(smiles)
    MW = Descriptors.MolWt(mol)
    MW_list.append(MW)
    form = CalcMolFormula(mol) 
    mol_form.append(form)
    
    totN_atoms, xyzcoords, mol2 = optimize(mol)
    xyzgeom_list.append(xyzcoords)
    N_atoms.append(totN_atoms)
    
    ic0 = IC0_calc(mol2)
    IC0_list.append(ic0)
    petit_index = petitjean_calc(mol2)
    petitjean_3D.append(petit_index)
    sic0_index = SIC0_calc(mol2)
    SIC0_list.append(sic0_index)
    gats = GATS1v_calc(mol2)
    GATS1v_list.append(gats)
    wiener = wiener_index(mol2)
    wiener_list.append(wiener)
    Z1 = zagreb_index1(mol2)
    Z1_list.append(Z1)

# %% [markdown]
# # Add columns with new properties to existing dataframe

# %%
df['Molecular Formula'] = mol_form
df['N_Atoms'] = N_atoms
df['Molecular Weight (g/mol)'] = MW_list
df['IC0'] = IC0_list
df['PJ3'] = petitjean_3D
df['SIC0'] = SIC0_list
df['GATS1v'] = GATS1v_list
df['Wiener'] = wiener_list
df['Z1'] = Z1_list
df
# Out:
#      ID                    Fuel  Boiling Point (K) Molecular Formula  N_Atoms  \
# 0   103                 Methane            111.650               CH4        5
# 1   104                Triptane            353.950             C7H16       23
# 2   105     2,2-Dimethylpropane            282.650             C5H12       17
# 3   106      2,2-Dimethylbutane            322.850             C6H14       20
# 4   107         Vinylacetylene             278.250              C4H4        8
# 5   108         Methylacetylene            249.950              C3H4        7
# 22                    68.075  1.392147  0.243647  0.439174  0.951887      15
# 23                    84.143  1.392147  0.257360  0.439174  0.731943      15
# 24                    44.053  1.378783  0.309207  0.491133  1.319696       3
# 25                    84.118  1.263809  0.287018  0.331939  1.234592      27
# 26                    43.069  1.298795  0.305844  0.432932  1.311735       3
# 27                    72.107  1.238901  0.208931  0.334798  1.400783      15
# 28                    66.103  0.994030  0.246880  0.287339  1.000000      15
# 29                    86.134  1.198192  0.292732  0.299548  1.418997      27
# 30                    76.145  0.918296  0.500000  0.579380  1.500000       4
# 31                    34.083  0.918296  0.312842  0.579380  1.500000       0
#
#       Z1
# 0    0.0
# 1   30.0
# 2   20.0
# 3   24.0
# 4   10.0
# 5    6.0
# 6   10.0
# 7   22.0
# 8   14.0
# 9   34.0
# 10   2.0
# 11  12.0
# 12  12.0
# 13  10.0
# 14  10.0
# 15  12.0
# 16  12.0
# 17  10.0
# 18  20.0
# 19  14.0
# 20   6.0
# 21  46.0
# 22  20.0
# 23  20.0
# 24  12.0
# 25  24.0
# 26  12.0
# 27  20.0
# 28  20.0
# 29  24.0
# 30   6.0
# 31   0.0

# %% [markdown]
# # Import molecular geometries from cartesian xyz coordinates

# %%
psi4_mols = []
for geo in xyzgeom_list:
    psi4mol = psi4.geometry(geo)
    psi4_mols.append(psi4mol)
    
E_list = []
wfn_list = []
homo_list = []
lumo_list = []
DM_list = []
const = psi4.constants.dipmom_au2debye #atomic units to Debye conversion factor for dipoles

# %% [markdown]
# # Molecular structure optimization round 2 + calculate HOMO, LUMO, and DM

# %%
psi4.set_options({'reference': 'uhf'})

k=102
for molec in psi4_mols: #iterate over list of molecular geometries
    
    E, wfn= psi4.optimize("B3LYP/6-31G*", molecule = molec,return_wfn=True) #returns energy and wavefunction of molecule
    
    E_list.append(E)
    wfn_list.append(wfn)
    
    HOMO = ( np.array(wfn.epsilon_a_subset("AO", "ALL")) )[wfn.nalpha()-1]
    LUMO = ( np.array(wfn.epsilon_a_subset("AO", "ALL")) )[wfn.nalpha()]
    dipole_xyz = wfn.variable("SCF DIPOLE")
    dipole_debye = np.linalg.norm(dipole_xyz) *const
  
    homo_list.append(HOMO)
    lumo_list.append(LUMO)
    DM_list.append(dipole_debye)
    
    k+=1
    strID = "fuel"+str(k)+ ".xyz"
    molec.save_xyz_file(strID,1) #write final optimized geometry to XYZ file
    print("Fuel "+str(k)+" done, "+ "k: "+str(k))
# Out:
# Optimizer: Optimization complete!
# Fuel 103 done, k: 103
# Optimizer: Optimization complete!
# Fuel 104 done, k: 104
# Optimizer: Optimization complete!
# Fuel 105 done, k: 105
# Optimizer: Optimization complete!
# Fuel 106 done, k: 106
# Optimizer: Optimization complete!
# Fuel 107 done, k: 107
# Optimizer: Optimization complete!
# Fuel 108 done, k: 108
# Optimizer: Optimization complete!
# Fuel 109 done, k: 109
# Optimizer: Optimization complete!
# Fuel 110 done, k: 110
# Optimizer: Optimization complete!
# Fuel 111 done, k: 111
# Optimizer: Optimization complete!
# Fuel 112 done, k: 112
# Optimizer: Optimization complete!
# Fuel 113 done, k: 113
# Optimizer: Optimization complete!
# Fuel 114 done, k: 114
# Optimizer: Optimization complete!
# Fuel 115 done, k: 115
# Optimizer: Optimization complete!
# Fuel 116 done, k: 116
# Optimizer: Optimization complete!
# Fuel 117 done, k: 117
# Optimizer: Optimization complete!
# Fuel 118 done, k: 118
# Optimizer: Optimization complete!
# Fuel 119 done, k: 119
# Optimizer: Optimization complete!
# Fuel 120 done, k: 120
# Optimizer: Optimization complete!
# Fuel 121 done, k: 121
# Optimizer: Optimization complete!
# Fuel 122 done, k: 122
# Optimizer: Optimization complete!
# Fuel 123 done, k: 123
# Optimizer: Optimization complete!
# Fuel 124 done, k: 124
# Optimizer: Optimization complete!
# Fuel 125 done, k: 125
# Optimizer: Optimization complete!
# Fuel 126 done, k: 126
# Optimizer: Optimization complete!
# Fuel 127 done, k: 127
# Optimizer: Optimization complete!
# Fuel 128 done, k: 128
# Optimizer: Optimization complete!
# Fuel 129 done, k: 129
# Optimizer: Optimization complete!
# Fuel 130 done, k: 130
# Optimizer: Optimization complete!
# Fuel 131 done, k: 131
# Optimizer: Optimization complete!
# Fuel 132 done, k: 132
# Optimizer: Optimization complete!
# Fuel 133 done, k: 133
# Optimizer: Optimization complete!
# Fuel 134 done, k: 134

# %% [markdown]
# # Add HOMO, LUMO, DM lists to dataframe and save as CSV file

# %%
df2 = pd.DataFrame(list(zip(homo_list,lumo_list,DM_list)), columns=['HOMO','LUMO','DM'])
df2
# Out:
#         HOMO      LUMO        DM
# 0  -0.389060  0.117915  0.000004
# 1  -0.296902  0.075274  0.040989
# 2  -0.314737  0.075818  0.000123
# 3  -0.303212  0.076642  0.040468
# 4  -0.241190 -0.025804  0.332664
# 5  -0.259467  0.061985  0.686964
# 6  -0.229010 -0.022510  0.000005
# 7  -0.257193  0.055737  0.635912
# 8  -0.235301  0.033577  0.042378
# 9  -0.237243  0.024634  0.419141
# 10 -0.264526  0.075255  1.694349
# 11 -0.233066  0.027334  1.843382
# 12 -0.261126  0.073618  1.615892
# 13 -0.273809 -0.016772  2.289544
# 14 -0.289892  0.029440  2.251041
# 15 -0.288677  0.025558  2.372792
# 16 -0.229269  0.076785  1.342699
# 17 -0.253489 -0.019130  2.546144
# 18 -0.249549 -0.010348  1.681609
# 19 -0.266481  0.096475  0.288169
# 20 -0.217007  0.043808  1.721915
# 21 -0.222619  0.032180  0.461415
# 22 -0.224442  0.019690  0.631067
# 23 -0.232768 -0.007631  0.633181
# 24 -0.267040  0.105587  1.949308
# 25 -0.210177  0.044667  1.253082
# 26 -0.243784  0.080287  1.774533
# 27 -0.237370  0.087547  1.789541
# 28 -0.211544 -0.009824  0.437502
# 29 -0.242654  0.090086  1.410105
# 30 -0.277767 -0.074936  0.000002
# 31 -0.261521  0.019569  1.426628

# %%
df3 = pd.concat([df,df2], axis=1)
df3
# Out:
#      ID                    Fuel  Boiling Point (K) Molecular Formula  N_Atoms  \
# 0   103                 Methane            111.650               CH4        5
# 1   104                Triptane            353.950             C7H16       23
# 2   105     2,2-Dimethylpropane            282.650             C5H12       17
# 3   106      2,2-Dimethylbutane            322.850             C6H14       20
# 4   107         Vinylacetylene             278.250              C4H4        8
# 5   108         Methylacetylene            249.950              C3H4        7
# 6   109           1,3-Butadiene            268.750              C4H6       10
# 7   110               1-Heptyne            372.850             C7H12       19
# 8   111               2-Pentene            309.883             C5H10       15
# 9   112           Diisobutylene            374.350             C8H16       24
# 10  113                Methanol            337.850              CH4O        6
# 11  114    Isopropyl mercaptan             325.650             C3H8S       12
# 12  115      Isopropyl alcohol             183.650             C3H8O       12
# 13  116         Allyl chloride             318.250            C3H5Cl        9
# 14  117      n-Propyl chloride             319.650            C3H7Cl       11
# 15  118     Isopropyl chloride             308.850            C3H7Cl       11
# 16  119         Isopropylamine             304.850             C3H9N       13
# 17  120        Propionaldehyde             321.150             C3H6O       10
# 18  121          Vinyl acetate             345.650            C4H6O2       12
# 19  122       Dimethoxymethane             315.150            C3H8O2       13
# 20  123       Dimethyl sulfide             310.450             C2H6S        9
# 21  124  Di-tert-butyl peroxide            384.150           C8H18O2       28
# 22  125                  Furan             304.650             C4H4O        9
# 23  126               Thiophene            357.150             C4H4S        9
# 24  127          Ethylene oxide            283.750             C2H4O        7
# 25  128           Dihydropyran             359.150             C5H8O       14
# 26  129           Ethylenimine             329.150             C2H5N        8
# 27  130        Tetrahydrofuran             338.150             C4H8O       13
# 28  131         Cyclopentadiene            314.150              C5H6       11
# 29  132         Tetrahydropyran            361.150            C5H10O       16
# 30  133        Carbon disulfide            319.150               CS2        3
# 31  134       Hydrogen sulfide             212.820               H2S        3
#
#     Molecular Weight (g/mol)       IC0       PJ3      SIC0    GATS1v  Wiener  \
# 0                     16.043  0.721928  0.387628  0.310918  2.500000       0
# 1                    100.205  0.886541  0.373455  0.195983  1.642857      42
# 2                     72.151  0.873981  0.495820  0.213820  1.700000      16
# 3                     86.178  0.881291  0.375670  0.203912  1.666667      28
# 4                     52.076  1.000000  0.392134  0.333333  1.000000      10
# 5                     40.065  0.985228  0.465948  0.350945  1.166667       4
# 6                     54.092  0.970951  0.377314  0.292285  1.250000      10
# 7                     96.173  0.949452  0.471906  0.223509  1.357143      56
# 8                     70.135  0.918296  0.474650  0.235045  1.500000      20
# 9                    112.216  0.918296  0.466897  0.200284  1.500000      66
# 10                    32.042  1.251629  0.318030  0.484196  1.875736       1
# 11                    76.164  1.188722  0.447878  0.331586  1.408362       9
# 12                    60.096  1.188722  0.494968  0.331586  1.646057       9
