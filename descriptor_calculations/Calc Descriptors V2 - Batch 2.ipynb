# %%
import psi4
from rdkit import Chem
from rdkit.Chem import AllChem
import numpy as np
import pandas as pd
from rdkit.Chem import Descriptors
from rdkit.Chem.rdMolDescriptors import CalcMolFormula

# %% [markdown]
# # Import CSV file containing fuels

# %%
df = pd.read_csv('FuelList1.csv')
df.drop(['Boiling Point (F)'],axis='columns',inplace=True)
df.drop(df.index[70:102],inplace=True)
df
# Out:
#     ID                    Fuel  Boiling Point (K)
# 0    1  1,3,5-trimethylbenzene         437.872222
# 1    2                1-Butene         267.038889
# 2    3               1-Pentene         303.038889
# 3    4     2,3-Dimethylpentane         363.150000
# 4    5      2,5-dimethylhexane         382.261111
# ..  ..                     ...                ...
# 65  66         Methyl chloride         248.927778
# 66  67        Methyl decanoate         497.150000
# 67  68          Methyl formate         304.950000
# 68  69     Methyl methacrylate         374.150000
# 69  70       Methylcyclohexane         374.150000
#
# [70 rows x 3 columns]

# %%
df.drop(df.index[0:39],inplace=True)
df.reset_index(drop=True,inplace=True)
df
# Out:
#     ID                 Fuel  Boiling Point (K)
# 0   40        Ethyl bromide         311.538889
# 1   41       Ethyl chloride         285.427778
# 2   42        Ethyl formate         327.372222
# 3   43         ethylbenzene         409.372222
# 4   44     ethylcyclohexane         402.538889
# 5   45             Ethylene         169.427778
# 6   46  Ethylene dichloride         356.650000
# 7   47         Formaldehyde         254.150000
# 8   48             Furfural         434.872222
# 9   49               Hexane         342.150000
# 10  50      Isoamyl alcohol         405.372222
# 11  51            Isobutane         261.372222
# 12  52            Isobutene         266.261111
# 13  53            Isocetane         513.205556
# 14  54          Isododecane         453.150000
# 15  55            Isooctane         372.150000
# 16  56           Isopentane         300.950000
# 17  57          Isopentanol         405.372222
# 18  58    Isopentyl acetate         415.150000
# 19  59    Isopropyl acetate         362.150000
# 20  60    Isopropyl alcohol         355.650000
# 21  61         Methacrolein         342.150000
# 22  62       Methyl acetate         330.038889
# 23  63       Methyl alcohol         337.761111
# 24  64         Methyl amine         266.650000
# 25  65       Methyl bromide         276.705556
# 26  66      Methyl chloride         248.927778
# 27  67     Methyl decanoate         497.150000
# 28  68       Methyl formate         304.950000
# 29  69  Methyl methacrylate         374.150000
# 30  70    Methylcyclohexane         374.150000

# %% [markdown]
# # Function to query the NIH database for molecules matching the input string and then perform chemical structure identifier conversion: IUPAC to SMILES

# %%
from urllib.request import urlopen
from urllib.parse import quote
from rdkit.Chem import AllChem

#Chemical name to SMILES:

def toSmiles(ids):
    try:
        url = 'https://cactus.nci.nih.gov/chemical/structure/' + quote(ids) + '/smiles'
        ans = urlopen(url).read().decode('utf8')
        return ans
    except:
        return 'Enter a valid IUPAC name'

# %% [markdown]
# # Generate SMILES column and add it to existing dataframe

# %%
fuel_name = df['Fuel']
smiles_list = []
index = -1
for ids in fuel_name:
    index+=1
    smiles_list.append(toSmiles(ids))
    if toSmiles(ids) == 'Enter a valid IUPAC name':
        print(ids + ' failed at index ' + str(index))
# Out:
# Isocetane failed at index 13

# %%
smiles_list[13] = 'CC(CC(C)(C)C)CC(C)(C)CC(C)(C)C'
df['SMIILES'] = smiles_list
df
# Out:
#     ID                 Fuel  Boiling Point (K)                         SMIILES
# 0   40        Ethyl bromide         311.538889                            CCBr
# 1   41       Ethyl chloride         285.427778                            CCCl
# 2   42        Ethyl formate         327.372222                          CCOC=O
# 3   43         ethylbenzene         409.372222                      CCc1ccccc1
# 4   44     ethylcyclohexane         402.538889                      CCC1CCCCC1
# 5   45             Ethylene         169.427778                             C=C
# 6   46  Ethylene dichloride         356.650000                          ClCCCl
# 7   47         Formaldehyde         254.150000                             C=O
# 8   48             Furfural         434.872222                      O=Cc1occc1
# 9   49               Hexane         342.150000                          CCCCCC
# 10  50      Isoamyl alcohol         405.372222                        CC(C)CCO
# 11  51            Isobutane         261.372222                          CC(C)C
# 12  52            Isobutene         266.261111                         CC(C)=C
# 13  53            Isocetane         513.205556  CC(CC(C)(C)C)CC(C)(C)CC(C)(C)C
# 14  54          Isododecane         453.150000                  CCCCCCCCCC(C)C
# 15  55            Isooctane         372.150000                      CCCCCC(C)C
# 16  56           Isopentane         300.950000                         CCC(C)C
# 17  57          Isopentanol         405.372222                        CC(C)CCO
# 18  58    Isopentyl acetate         415.150000                  CC(C)CCOC(C)=O
# 19  59    Isopropyl acetate         362.150000                    CC(C)OC(C)=O
# 20  60    Isopropyl alcohol         355.650000                          CC(C)O
# 21  61         Methacrolein         342.150000                       CC(=C)C=O
# 22  62       Methyl acetate         330.038889                        COC(C)=O
# 23  63       Methyl alcohol         337.761111                              CO
# 24  64         Methyl amine         266.650000                              CN
# 25  65       Methyl bromide         276.705556                             CBr
# 26  66      Methyl chloride         248.927778                             CCl
# 27  67     Methyl decanoate         497.150000                CCCCCCCCCC(=O)OC
# 28  68       Methyl formate         304.950000                           COC=O
# 29  69  Methyl methacrylate         374.150000                   COC(=O)C(C)=C
# 30  70    Methylcyclohexane         374.150000                       CC1CCCCC1

# %% [markdown]
# # Define function that will optimize a molecule's 3D structure to obtain the structure with the lowest energy - Round 1
# # **Important for desriptor calculations

# %%
def optimize(m):
    """ 
        Input: RDKit molecule object
        
        Optimizes molecular structure by applying the Merck molecular force field 94(MMFF94) before performing tasks:
        
        1. Calculates total number of atoms
        
        2. Coverts geometry of mol object to a string of xyz coordinates
    
    """
    m = Chem.AddHs(m)#add hydrogens to structure
    #Convert from 2D to 3D
    AllChem.EmbedMolecule(m,randomSeed=0xf00d,useExpTorsionAnglePrefs=True,useBasicKnowledge=True)#intialize molecular conformation
    AllChem.MMFFOptimizeMolecule(m,'MMFF94')#apply force field
    atoms = m.GetAtoms()
    string = "\n"
    for i, atom in enumerate(atoms):
        pos = m.GetConformer().GetAtomPosition(atom.GetIdx())
        string += "{} {} {} {}\n".format(atom.GetSymbol(), pos.x, pos.y, pos.z)
    string += "units angstrom\n"
    string += "symmetry c1\n"
    #-------------------------------------------
    totAtoms = m.GetNumAtoms()
    #-----------------------------------------------
    
    
    return totAtoms, string, m

# %% [markdown]
# # Calculate descriptors: Number of atoms, molecular weight, IC0, PJI3, SIC0, GATS1v, Wiener Index, Zagreb Index

# %%
from mordred import InformationContent
from mordred import GeometricalIndex
from mordred import Autocorrelation
from mordred import WienerIndex
from mordred import ZagrebIndex

IC0_calc = InformationContent.InformationContent(order=0)
petitjean_calc = GeometricalIndex.PetitjeanIndex3D()
SIC0_calc = InformationContent.StructuralIC(order=0)
GATS1v_calc = Autocorrelation.GATS(order=1,prop='v')
wiener_index = WienerIndex.WienerIndex()
zagreb_index1 = ZagrebIndex.ZagrebIndex(version = 1) 



IC0_list = [] # Information content index (neighborhood symmetry of 0-order)
petitjean_3D = [] #3D petitjean shape index
SIC0_list = []
GATS1v_list = []
wiener_list= [] #stores wiener indices
Z1_list = [] #stores zagreb1 indices



MW_list = [] #stores molecular weight
mol_form = [] #stores molecular formulas
N_atoms = [] #stores number of atoms
xyzgeom_list = [] #stores xyz coordinates


for smiles in smiles_list:

    mol = Chem.MolFromSmiles(smiles)
    MW = Descriptors.MolWt(mol)
    MW_list.append(MW)
    form = CalcMolFormula(mol) 
    mol_form.append(form)
    
    totN_atoms, xyzcoords, mol2 = optimize(mol)
    xyzgeom_list.append(xyzcoords)
    N_atoms.append(totN_atoms)
    
    ic0 = IC0_calc(mol2)
    IC0_list.append(ic0)
    petit_index = petitjean_calc(mol2)
    petitjean_3D.append(petit_index)
    sic0_index = SIC0_calc(mol2)
    SIC0_list.append(sic0_index)
    gats = GATS1v_calc(mol2)
    GATS1v_list.append(gats)
    wiener = wiener_index(mol2)
    wiener_list.append(wiener)
    Z1 = zagreb_index1(mol2)
    Z1_list.append(Z1)

# %% [markdown]
# # Add columns with new properties to existing dataframe

# %%
df['Molecular Formula'] = mol_form
df['N_Atoms'] = N_atoms
df['Molecular Weight (g/mol)'] = MW_list
df['IC0'] = IC0_list
df['PJ3'] = petitjean_3D
df['SIC0'] = SIC0_list
df['GATS1v'] = GATS1v_list
df['Wiener'] = wiener_list
df['Z1'] = Z1_list
df
# Out:
#     ID                 Fuel  Boiling Point (K)  \
# 0   40        Ethyl bromide         311.538889
# 1   41       Ethyl chloride         285.427778
# 2   42        Ethyl formate         327.372222
# 3   43         ethylbenzene         409.372222
# 4   44     ethylcyclohexane         402.538889
# 5   45             Ethylene         169.427778
# 6   46  Ethylene dichloride         356.650000
# 7   47         Formaldehyde         254.150000
# 8   48             Furfural         434.872222
# 9   49               Hexane         342.150000
# 10  50      Isoamyl alcohol         405.372222
# 11  51            Isobutane         261.372222
# 12  52            Isobutene         266.261111
# 13  53            Isocetane         513.205556
# 14  54          Isododecane         453.150000
# 15  55            Isooctane         372.150000
# 16  56           Isopentane         300.950000
# 17  57          Isopentanol         405.372222
# 18  58    Isopentyl acetate         415.150000
# 19  59    Isopropyl acetate         362.150000
# 20  60    Isopropyl alcohol         355.650000
# 21  61         Methacrolein         342.150000
# 22  62       Methyl acetate         330.038889
# 23  63       Methyl alcohol         337.761111
# 24  64         Methyl amine         266.650000
# 25  65       Methyl bromide         276.705556
# 26  66      Methyl chloride         248.927778
# 27  67     Methyl decanoate         497.150000
# 28  68       Methyl formate         304.950000
# 29  69  Methyl methacrylate         374.150000
# 30  70    Methylcyclohexane         374.150000
#
#                            SMIILES Molecular Formula  N_Atoms  \
# 0                             CCBr            C2H5Br        8
# 1                             CCCl            C2H5Cl        8
# 2                           CCOC=O            C3H6O2       11
# 3                       CCc1ccccc1             C8H10       18
# 4                       CCC1CCCCC1             C8H16       24
# 5                              C=C              C2H4        6
# 6                           ClCCCl           C2H4Cl2        8
# 7                              C=O              CH2O        4
# 8                       O=Cc1occc1            C5H4O2       11
# 9                           CCCCCC             C6H14       20
# 10                        CC(C)CCO            C5H12O       18
# 11                          CC(C)C             C4H10       14
# 12                         CC(C)=C              C4H8       12
# 13  CC(CC(C)(C)C)CC(C)(C)CC(C)(C)C            C16H34       50
# 14                  CCCCCCCCCC(C)C            C12H26       38
# 15                      CCCCCC(C)C             C8H18       26
# 16                         CCC(C)C             C5H12       17
# 17                        CC(C)CCO            C5H12O       18
# 18                  CC(C)CCOC(C)=O           C7H14O2       23
# 19                    CC(C)OC(C)=O           C5H10O2       17
# 20                          CC(C)O             C3H8O       12
# 21                       CC(=C)C=O             C4H6O       11
# 22                        COC(C)=O            C3H6O2       11
# 23                              CO              CH4O        6
# 24                              CN              CH5N        7
# 25                             CBr             CH3Br        5
# 26                             CCl             CH3Cl        5
# 27                CCCCCCCCCC(=O)OC          C11H22O2       35
# 28                           COC=O            C2H4O2        8
# 29                   COC(=O)C(C)=C            C5H8O2       15
# 30                       CC1CCCCC1             C7H14       21
#
#     Molecular Weight (g/mol)       IC0       PJ3      SIC0    GATS1v  Wiener  \
# 0                    108.966  1.298795  0.434590  0.432932  1.028368       4
# 1                     64.515  1.298795  0.411810  0.432932  1.226676       4
# 2                     74.079  1.435371  0.347865  0.414915  1.520356      20
# 3                    106.168  0.991076  0.458236  0.237672  1.062500      64
# 4                    112.216  0.918296  0.468125  0.200284  1.437500      64
# 5                     28.054  0.918296  0.314547  0.355245  1.500000       1
# 6                     98.960  1.500000  0.259230  0.500000  0.886911      10
# 7                     30.026  1.500000  0.399053  0.750000  1.487738       1
# 8                     96.085  1.494919  0.418089  0.432128  0.910178      43
# 9                     86.178  0.881291  0.352204  0.203912  1.666667      35
# 10                    88.150  1.134970  0.471569  0.272180  1.590373      32
# 11                    58.124  0.863121  0.494961  0.226698  1.750000       9
# 12                    56.108  0.918296  0.498718  0.256152  1.500000       9
# 13                   226.448  0.904381  0.410746  0.160242  1.562500     468
# 14                   170.340  0.899744  0.483586  0.171447  1.583333     277
# 15                   114.232  0.890492  0.459535  0.189449  1.625000      79
# 16                    72.151  0.873981  0.373841  0.213820  1.700000      18
# 17                    88.150  1.134970  0.471569  0.272180  1.590373      32
# 18                   130.187  1.264673  0.473038  0.279575  1.504504     108
# 19                   102.133  1.332820  0.484445  0.326075  1.508257      48
# 20                    60.096  1.188722  0.494968  0.331586  1.646057       9
# 21                    70.091  1.322179  0.471280  0.382196  1.261049      18
# 22                    74.079  1.435371  0.386855  0.414915  1.520356      18
# 23                    32.042  1.251629  0.318030  0.484196  1.875736       1
# 24                    31.058  1.148835  0.309005  0.409223  1.908265       1
# 25                    94.939  1.370951  0.225666  0.590436  0.876547       1
# 26                    50.488  1.370951  0.251769  0.590436  1.107053       1
# 27                   186.295  1.181819  0.485075  0.230406  1.501987     346
# 28                    60.052  1.500000  0.431643  0.500000  1.540606      10
# 29                   100.117  1.399581  0.469475  0.358234  1.336742      46
# 30                    98.189  0.918296  0.358970  0.209069  1.428571      42
#
#       Z1
# 0    6.0
# 1    6.0
# 2   14.0
# 3   34.0
# 4   34.0
# 5    2.0
# 6   10.0
# 7    2.0
# 8   30.0
# 9   18.0
# 10  20.0
# 11  12.0
# 12  12.0
# 13  78.0
# 14  44.0
# 15  28.0
# 16  16.0
# 17  20.0
# 18  34.0
# 19  26.0
# 20  12.0
# 21  16.0
# 22  16.0
# 23   2.0
# 24   2.0
# 25   2.0
# 26   2.0
# 27  48.0
# 28  10.0
# 29  26.0
# 30  30.0

# %% [markdown]
# # Import molecular geometries from cartesian xyz coordinates

# %%
psi4_mols = []
for geo in xyzgeom_list:
    psi4mol = psi4.geometry(geo)
    psi4_mols.append(psi4mol)
    
E_list = []
wfn_list = []
homo_list = []
lumo_list = []
DM_list = []
const = psi4.constants.dipmom_au2debye #atomic units to Debye conversion factor for dipoles

# %% [markdown]
# # Molecular structure optimization round 2 + calculate HOMO, LUMO, and DM

# %%
psi4.set_options({'reference': 'uhf'})

k=39
for molec in psi4_mols: #iterate over list of molecular geometries
    
    E, wfn= psi4.optimize("B3LYP/6-31G*", molecule = molec,return_wfn=True) #returns energy and wavefunction of molecule
    
    E_list.append(E)
    wfn_list.append(wfn)
    
    HOMO = ( np.array(wfn.epsilon_a_subset("AO", "ALL")) )[wfn.nalpha()-1]
    LUMO = ( np.array(wfn.epsilon_a_subset("AO", "ALL")) )[wfn.nalpha()]
    dipole_xyz = wfn.variable("SCF DIPOLE")
    dipole_debye = np.linalg.norm(dipole_xyz) *const
  
    homo_list.append(HOMO)
    lumo_list.append(LUMO)
    DM_list.append(dipole_debye)
    
    k+=1
    strID = "fuel"+str(k)+ ".xyz"
    molec.save_xyz_file(strID,1) #write final optimized geometry to XYZ file
    print("Fuel "+str(k)+" done, "+ "k: "+str(k))
# Out:
# Optimizer: Optimization complete!
# Fuel 40 done, k: 40
# Optimizer: Optimization complete!
# Fuel 41 done, k: 41
# Optimizer: Optimization complete!
# Fuel 42 done, k: 42
# Optimizer: Optimization complete!
# Fuel 43 done, k: 43
# Optimizer: Optimization complete!
# Fuel 44 done, k: 44
# Optimizer: Optimization complete!
# Fuel 45 done, k: 45
# Optimizer: Optimization complete!
# Fuel 46 done, k: 46
# Optimizer: Optimization complete!
# Fuel 47 done, k: 47
# Optimizer: Optimization complete!
# Fuel 48 done, k: 48
# Optimizer: Optimization complete!
# Fuel 49 done, k: 49
# Optimizer: Optimization complete!
# Fuel 50 done, k: 50
# Optimizer: Optimization complete!
# Fuel 51 done, k: 51
# Optimizer: Optimization complete!
# Fuel 52 done, k: 52
# Optimizer: Optimization complete!
# Fuel 53 done, k: 53
# Optimizer: Optimization complete!
# Fuel 54 done, k: 54
# Optimizer: Optimization complete!
# Fuel 55 done, k: 55
# Optimizer: Optimization complete!
# Fuel 56 done, k: 56
# Optimizer: Optimization complete!
# Fuel 57 done, k: 57
# Optimizer: Optimization complete!
# Fuel 58 done, k: 58
# Optimizer: Optimization complete!
# Fuel 59 done, k: 59
# Optimizer: Optimization complete!
# Fuel 60 done, k: 60
# Optimizer: Optimization complete!
# Fuel 61 done, k: 61
# Optimizer: Optimization complete!
# Fuel 62 done, k: 62
# Optimizer: Optimization complete!
# Fuel 63 done, k: 63
# Optimizer: Optimization complete!
# Fuel 64 done, k: 64
# Optimizer: Optimization complete!
# Fuel 65 done, k: 65
# Optimizer: Optimization complete!
# Fuel 66 done, k: 66
# Optimizer: Optimization complete!
# Fuel 67 done, k: 67
# Optimizer: Optimization complete!
# Fuel 68 done, k: 68
# Optimizer: Optimization complete!
# Fuel 69 done, k: 69
# Optimizer: Optimization complete!
# Fuel 70 done, k: 70

# %% [markdown]
# # Add HOMO, LUMO, DM lists to dataframe and save as CSV file

# %%
df2 = pd.DataFrame(list(zip(homo_list,lumo_list,DM_list)), columns=['HOMO','LUMO','DM'])
df2
# Out:
#         HOMO      LUMO        DM
# 0  -0.273771 -0.005205  2.344247
# 1  -0.291561  0.027839  2.267049
# 2  -0.281113  0.007657  1.895545
# 3  -0.235742  0.005216  0.279909
# 4  -0.285769  0.080818  0.054273
# 5  -0.266618  0.018780  0.000009
# 6  -0.298933  0.006168  2.933239
# 7  -0.268489 -0.042115  2.186930
# 8  -0.249584 -0.061061  4.168316
# 9  -0.305762  0.093285  0.025680
# 10 -0.260795  0.077618  1.528052
# 11 -0.317671  0.086022  0.085211
# 12 -0.239579  0.031220  0.505144
# 13 -0.280856  0.059047  0.081554
# 14 -0.291372  0.082474  0.154264
# 15 -0.294644  0.076233  0.061056
# 16 -0.308885  0.086404  0.060671
# 17 -0.260795  0.077618  1.528052
# 18 -0.266678  0.016992  1.722832
# 19 -0.265557  0.017215  1.883950
# 20 -0.261126  0.073618  1.615892
# 21 -0.255130 -0.061072  2.838068
# 22 -0.269531  0.014508  1.778700
# 23 -0.264526  0.075255  1.694349
# 24 -0.228719  0.084477  1.471082
# 25 -0.278256 -0.006590  2.073162
# 26 -0.296443  0.025909  2.083153
# 27 -0.262956  0.015284  1.968666
# 28 -0.283680  0.005409  1.838430
# 29 -0.267693 -0.038256  1.674125
# 30 -0.287772  0.080411  0.089203

# %%
df3 = pd.concat([df,df2], axis=1)
df3
# Out:
#     ID                 Fuel  Boiling Point (K)  \
# 0   40        Ethyl bromide         311.538889
# 1   41       Ethyl chloride         285.427778
# 2   42        Ethyl formate         327.372222
# 3   43         ethylbenzene         409.372222
# 4   44     ethylcyclohexane         402.538889
# 5   45             Ethylene         169.427778
# 6   46  Ethylene dichloride         356.650000
# 7   47         Formaldehyde         254.150000
# 8   48             Furfural         434.872222
# 9   49               Hexane         342.150000
# 10  50      Isoamyl alcohol         405.372222
# 11  51            Isobutane         261.372222
# 12  52            Isobutene         266.261111
# 13  53            Isocetane         513.205556
# 14  54          Isododecane         453.150000
# 15  55            Isooctane         372.150000
# 16  56           Isopentane         300.950000
# 17  57          Isopentanol         405.372222
# 18  58    Isopentyl acetate         415.150000
# 19  59    Isopropyl acetate         362.150000
# 20  60    Isopropyl alcohol         355.650000
# 21  61         Methacrolein         342.150000
# 22  62       Methyl acetate         330.038889
# 23  63       Methyl alcohol         337.761111
# 24  64         Methyl amine         266.650000
# 25  65       Methyl bromide         276.705556
# 26  66      Methyl chloride         248.927778
# 27  67     Methyl decanoate         497.150000
# 28  68       Methyl formate         304.950000
# 29  69  Methyl methacrylate         374.150000
# 30  70    Methylcyclohexane         374.150000
#
#                            SMIILES Molecular Formula  N_Atoms  \
# 0                             CCBr            C2H5Br        8
# 1                             CCCl            C2H5Cl        8
# 2                           CCOC=O            C3H6O2       11
# 3                       CCc1ccccc1             C8H10       18
# 4                       CCC1CCCCC1             C8H16       24
# 5                              C=C              C2H4        6
# 6                           ClCCCl           C2H4Cl2        8
# 7                              C=O              CH2O        4
# 8                       O=Cc1occc1            C5H4O2       11
# 9                           CCCCCC             C6H14       20
# 10                        CC(C)CCO            C5H12O       18
# 11                          CC(C)C             C4H10       14
# 12                         CC(C)=C              C4H8       12
# 13  CC(CC(C)(C)C)CC(C)(C)CC(C)(C)C            C16H34       50
# 14                  CCCCCCCCCC(C)C            C12H26       38
# 15                      CCCCCC(C)C             C8H18       26
# 16                         CCC(C)C             C5H12       17
# 17                        CC(C)CCO            C5H12O       18
# 18                  CC(C)CCOC(C)=O           C7H14O2       23
# 19                    CC(C)OC(C)=O           C5H10O2       17
# 20                          CC(C)O             C3H8O       12
# 21                       CC(=C)C=O             C4H6O       11
# 22                        COC(C)=O            C3H6O2       11
# 23                              CO              CH4O        6
# 24                              CN              CH5N        7
# 25                             CBr             CH3Br        5
# 26                             CCl             CH3Cl        5
# 27                CCCCCCCCCC(=O)OC          C11H22O2       35
# 28                           COC=O            C2H4O2        8
# 29                   COC(=O)C(C)=C            C5H8O2       15
# 30                       CC1CCCCC1             C7H14       21
#
#     Molecular Weight (g/mol)       IC0       PJ3      SIC0    GATS1v  Wiener  \
# 0                    108.966  1.298795  0.434590  0.432932  1.028368       4
# 1                     64.515  1.298795  0.411810  0.432932  1.226676       4
# 2                     74.079  1.435371  0.347865  0.414915  1.520356      20
# 3                    106.168  0.991076  0.458236  0.237672  1.062500      64
# 4                    112.216  0.918296  0.468125  0.200284  1.437500      64
# 5                     28.054  0.918296  0.314547  0.355245  1.500000       1
# 6                     98.960  1.500000  0.259230  0.500000  0.886911      10
# 7                     30.026  1.500000  0.399053  0.750000  1.487738       1
# 8                     96.085  1.494919  0.418089  0.432128  0.910178      43
# 9                     86.178  0.881291  0.352204  0.203912  1.666667      35
# 10                    88.150  1.134970  0.471569  0.272180  1.590373      32
# 11                    58.124  0.863121  0.494961  0.226698  1.750000       9
# 12                    56.108  0.918296  0.498718  0.256152  1.500000       9
# 13                   226.448  0.904381  0.410746  0.160242  1.562500     468
# 14                   170.340  0.899744  0.483586  0.171447  1.583333     277
# 15                   114.232  0.890492  0.459535  0.189449  1.625000      79
# 16                    72.151  0.873981  0.373841  0.213820  1.700000      18
# 17                    88.150  1.134970  0.471569  0.272180  1.590373      32
# 18                   130.187  1.264673  0.473038  0.279575  1.504504     108
# 19                   102.133  1.332820  0.484445  0.326075  1.508257      48
# 20                    60.096  1.188722  0.494968  0.331586  1.646057       9
# 21                    70.091  1.322179  0.471280  0.382196  1.261049      18
# 22                    74.079  1.435371  0.386855  0.414915  1.520356      18
# 23                    32.042  1.251629  0.318030  0.484196  1.875736       1
# 24                    31.058  1.148835  0.309005  0.409223  1.908265       1
# 25                    94.939  1.370951  0.225666  0.590436  0.876547       1
# 26                    50.488  1.370951  0.251769  0.590436  1.107053       1
# 27                   186.295  1.181819  0.485075  0.230406  1.501987     346
# 28                    60.052  1.500000  0.431643  0.500000  1.540606      10
# 29                   100.117  1.399581  0.469475  0.358234  1.336742      46
# 30                    98.189  0.918296  0.358970  0.209069  1.428571      42
#
#       Z1      HOMO      LUMO        DM
# 0    6.0 -0.273771 -0.005205  2.344247
# 1    6.0 -0.291561  0.027839  2.267049
# 2   14.0 -0.281113  0.007657  1.895545
# 3   34.0 -0.235742  0.005216  0.279909
# 4   34.0 -0.285769  0.080818  0.054273
# 5    2.0 -0.266618  0.018780  0.000009
# 6   10.0 -0.298933  0.006168  2.933239
# 7    2.0 -0.268489 -0.042115  2.186930
# 8   30.0 -0.249584 -0.061061  4.168316
# 9   18.0 -0.305762  0.093285  0.025680
# 10  20.0 -0.260795  0.077618  1.528052
# 11  12.0 -0.317671  0.086022  0.085211
# 12  12.0 -0.239579  0.031220  0.505144
# 13  78.0 -0.280856  0.059047  0.081554
# 14  44.0 -0.291372  0.082474  0.154264
# 15  28.0 -0.294644  0.076233  0.061056
# 16  16.0 -0.308885  0.086404  0.060671
# 17  20.0 -0.260795  0.077618  1.528052
# 18  34.0 -0.266678  0.016992  1.722832
# 19  26.0 -0.265557  0.017215  1.883950
# 20  12.0 -0.261126  0.073618  1.615892
# 21  16.0 -0.255130 -0.061072  2.838068
# 22  16.0 -0.269531  0.014508  1.778700
# 23   2.0 -0.264526  0.075255  1.694349
# 24   2.0 -0.228719  0.084477  1.471082
# 25   2.0 -0.278256 -0.006590  2.073162
# 26   2.0 -0.296443  0.025909  2.083153
# 27  48.0 -0.262956  0.015284  1.968666
# 28  10.0 -0.283680  0.005409  1.838430
# 29  26.0 -0.267693 -0.038256  1.674125
# 30  30.0 -0.287772  0.080411  0.089203

# %%
df3.to_csv('FuelDescriptors2.csv', encoding='utf-8', index=False)
