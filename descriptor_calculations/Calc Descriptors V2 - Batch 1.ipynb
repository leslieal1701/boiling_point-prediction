# %%
import psi4
from rdkit import Chem
from rdkit.Chem import AllChem
import numpy as np
import pandas as pd
from rdkit.Chem import Descriptors
from rdkit.Chem.rdMolDescriptors import CalcMolFormula

# %% [markdown]
# # Import CSV file containing fuels

# %%
df = pd.read_csv('FuelList1.csv')
df.drop(['Boiling Point (F)'],axis='columns',inplace=True)
df.drop(df.index[39:102],inplace=True)
df
# Out:
#     ID                      Fuel  Boiling Point (K)
# 0    1    1,3,5-trimethylbenzene         437.872222
# 1    2                  1-Butene         267.038889
# 2    3                 1-Pentene         303.038889
# 3    4       2,3-Dimethylpentane         363.150000
# 4    5        2,5-dimethylhexane         382.261111
# 5    6  2,6,10-trimethyldodecane         522.250000
# 6    7                  2-Butene         277.150000
# 7    8                2-Hexanone         401.150000
# 8    9           2-methylheptane         389.150000
# 9   10               2-Pentanone         374.150000
# 10  11           3-methylheptane         393.150000
# 11  12              Acetaldehyde         293.350000
# 12  13               Acetic acid         391.150000
# 13  14                   Acetone         329.150000
# 14  15                 Acetylene         189.150000
# 15  16                  Acrolein         326.150000
# 16  17             Acrylonitrile         350.150000
# 17  18             Allyl alcohol         370.150000
# 18  19                   Aniline         457.261111
# 19  20                   Benzene         353.261111
# 20  21                    Butane         272.150000
# 21  22             Butyl acetate         399.150000
# 22  23            Butyl chloride         351.650000
# 23  24             Chlorobenzene         405.150000
# 24  25               Cyclohexane         353.872222
# 25  26              cyclopentane         322.372222
# 26  27              Cyclopropane         240.288889
# 27  28                   decalin         463.150000
# 28  29                    Decane         447.261111
# 29  30             Diethyl amine         328.650000
# 30  31             Diethyl ether         307.750000
# 31  32            Dimethyl amine         280.538889
# 32  33            dimethyl ether         249.150000
# 33  34                   Dioxane         374.261111
# 34  35         Diisopropyl ether         342.038889
# 35  36                    Ethane         184.538889
# 36  37             Ethyl acetate         350.372222
# 37  38             Ethyl alcohol         159.038889
# 38  39               Ethyl amine         289.761111

# %% [markdown]
# # Function to query the NIH database for molecules matching the input string and then perform chemical structure identifier conversion: IUPAC to SMILES

# %%
from urllib.request import urlopen
from urllib.parse import quote
from rdkit.Chem import AllChem

#Chemical name to SMILES:

def toSmiles(ids):
    try:
        url = 'https://cactus.nci.nih.gov/chemical/structure/' + quote(ids) + '/smiles'
        ans = urlopen(url).read().decode('utf8')
        return ans
    except:
        return 'Enter a valid IUPAC name'

# %% [markdown]
# # Generate SMILES column and add it to existing dataframe

# %%
fuel_name = df['Fuel']
smiles_list = []
index = -1
for ids in fuel_name:
    index+=1
    smiles_list.append(toSmiles(ids))
    if toSmiles(ids) == 'Enter a valid IUPAC name':
        print(ids + ' failed at index ' + str(index))

# %% [markdown]
# # Define function that will optimize a molecule's 3D structure to obtain the structure with the lowest energy - Round 1
# # **Important for desriptor calculations

# %%
def optimize(m):
    """ 
        Input: RDKit molecule object
        
        Optimizes molecular structure by applying the Merck molecular force field 94(MMFF94) before performing tasks:
        
        1. Calculates total number of atoms
        
        2. Coverts geometry of mol object to a string of xyz coordinates
    
    """
    m = Chem.AddHs(m)#add hydrogens to structure
    #Convert from 2D to 3D
    AllChem.EmbedMolecule(m,randomSeed=0xf00d,useExpTorsionAnglePrefs=True,useBasicKnowledge=True)#intialize molecular conformation
    AllChem.MMFFOptimizeMolecule(m,'MMFF94')#apply force field
    atoms = m.GetAtoms()
    string = "\n"
    for i, atom in enumerate(atoms):
        pos = m.GetConformer().GetAtomPosition(atom.GetIdx())
        string += "{} {} {} {}\n".format(atom.GetSymbol(), pos.x, pos.y, pos.z)
    string += "units angstrom\n"
    string += "symmetry c1\n"
    #-------------------------------------------
    totAtoms = m.GetNumAtoms()
    #-----------------------------------------------
    
    
    return totAtoms, string, m

# %% [markdown]
# # Calculate descriptors: Number of atoms, molecular weight, IC0, PJI3, SIC0, GATS1v, Wiener Index, Zagreb Index

# %%
from mordred import InformationContent
from mordred import GeometricalIndex
from mordred import Autocorrelation
from mordred import WienerIndex
from mordred import ZagrebIndex

IC0_calc = InformationContent.InformationContent(order=0)
petitjean_calc = GeometricalIndex.PetitjeanIndex3D()
SIC0_calc = InformationContent.StructuralIC(order=0)
GATS1v_calc = Autocorrelation.GATS(order=1,prop='v')
wiener_index = WienerIndex.WienerIndex()
zagreb_index1 = ZagrebIndex.ZagrebIndex(version = 1) 



IC0_list = [] # Information content index (neighborhood symmetry of 0-order)
petitjean_3D = [] #3D petitjean shape index
SIC0_list = []
GATS1v_list = []
wiener_list= [] #stores wiener indices
Z1_list = [] #stores zagreb1 indices



MW_list = [] #stores molecular weight
mol_form = [] #stores molecular formulas
N_atoms = [] #stores number of atoms
xyzgeom_list = [] #stores xyz coordinates


for smiles in smiles_list:

    mol = Chem.MolFromSmiles(smiles)
    MW = Descriptors.MolWt(mol)
    MW_list.append(MW)
    form = CalcMolFormula(mol) 
    mol_form.append(form)
    
    totN_atoms, xyzcoords, mol2 = optimize(mol)
    xyzgeom_list.append(xyzcoords)
    N_atoms.append(totN_atoms)
    
    ic0 = IC0_calc(mol2)
    IC0_list.append(ic0)
    petit_index = petitjean_calc(mol2)
    petitjean_3D.append(petit_index)
    sic0_index = SIC0_calc(mol2)
    SIC0_list.append(sic0_index)
    gats = GATS1v_calc(mol2)
    GATS1v_list.append(gats)
    wiener = wiener_index(mol2)
    wiener_list.append(wiener)
    Z1 = zagreb_index1(mol2)
    Z1_list.append(Z1)

# %% [markdown]
# # Add columns with new properties to existing dataframe

# %%
df['Molecular Formula'] = mol_form
df['N_Atoms'] = N_atoms
df['Molecular Weight (g/mol)'] = MW_list
df['IC0'] = IC0_list
df['PJ3'] = petitjean_3D
df['SIC0'] = SIC0_list
df['GATS1v'] = GATS1v_list
df['Wiener'] = wiener_list
df['Z1'] = Z1_list
df
# Out:
#     ID                      Fuel  Boiling Point (K) Molecular Formula  \
# 0    1    1,3,5-trimethylbenzene         437.872222             C9H12
# 1    2                  1-Butene         267.038889              C4H8
# 2    3                 1-Pentene         303.038889             C5H10
# 3    4       2,3-Dimethylpentane         363.150000             C7H16
# 4    5        2,5-dimethylhexane         382.261111             C8H18
# 5    6  2,6,10-trimethyldodecane         522.250000            C15H32
# 6    7                  2-Butene         277.150000              C4H8
# 7    8                2-Hexanone         401.150000            C6H12O
# 8    9           2-methylheptane         389.150000             C8H18
# 9   10               2-Pentanone         374.150000            C5H10O
# 10  11           3-methylheptane         393.150000             C8H18
# 11  12              Acetaldehyde         293.350000             C2H4O
# 12  13               Acetic acid         391.150000            C2H4O2
# 13  14                   Acetone         329.150000             C3H6O
# 14  15                 Acetylene         189.150000              C2H2
# 15  16                  Acrolein         326.150000             C3H4O
# 16  17             Acrylonitrile         350.150000             C3H3N
# 17  18             Allyl alcohol         370.150000             C3H6O
# 18  19                   Aniline         457.261111             C6H7N
# 19  20                   Benzene         353.261111              C6H6
# 20  21                    Butane         272.150000             C4H10
# 21  22             Butyl acetate         399.150000           C6H12O2
# 22  23            Butyl chloride         351.650000            C4H9Cl
# 23  24             Chlorobenzene         405.150000            C6H5Cl
# 24  25               Cyclohexane         353.872222             C6H12
# 25  26              cyclopentane         322.372222             C5H10
# 26  27              Cyclopropane         240.288889              C3H6
# 27  28                   decalin         463.150000            C10H18
# 28  29                    Decane         447.261111            C10H22
# 29  30             Diethyl amine         328.650000            C4H11N
# 30  31             Diethyl ether         307.750000            C4H10O
# 31  32            Dimethyl amine         280.538889             C2H7N
# 32  33            dimethyl ether         249.150000             C2H6O
# 33  34                   Dioxane         374.261111            C4H8O2
# 34  35         Diisopropyl ether         342.038889            C6H14O
# 35  36                    Ethane         184.538889              C2H6
# 36  37             Ethyl acetate         350.372222            C4H8O2
# 37  38             Ethyl alcohol         159.038889             C2H6O
# 38  39               Ethyl amine         289.761111             C2H7N
#
#     N_Atoms  Molecular Weight (g/mol)       IC0       PJ3      SIC0    GATS1v  \
# 0        21                   120.195  0.985228  0.318633  0.224307  1.111111
# 1        12                    56.108  0.918296  0.363684  0.256152  1.500000
# 2        15                    70.135  0.918296  0.372016  0.235045  1.500000
# 3        23                   100.205  0.886541  0.454902  0.195983  1.642857
# 4        26                   114.232  0.890492  0.374392  0.189449  1.625000
# 5        47                   212.421  0.903454  0.479094  0.162650  1.566667
# 6        12                    56.108  0.918296  0.392235  0.256152  1.500000
# 7        19                   100.161  1.167437  0.423096  0.274825  1.492303
# 8        26                   114.232  0.890492  0.459535  0.189449  1.625000
# 9        16                    86.134  1.198192  0.446664  0.299548  1.491124
# 10       26                   114.232  0.890492  0.424405  0.189449  1.625000
# 11        7                    44.053  1.378783  0.310932  0.491133  1.484932
# 12        8                    60.052  1.500000  0.462753  0.500000  1.270303
# 13       10                    58.080  1.295462  0.499381  0.389973  1.487454
# 14        4                    26.038  1.000000  0.319878  0.500000  1.000000
# 15        8                    56.064  1.405639  0.470907  0.468546  1.191537
# 16        7                    53.064  1.448816  0.429122  0.516079  1.020275
# 17       10                    58.080  1.295462  0.430942  0.389973  1.335317
# 18       14                    93.129  1.295836  0.332646  0.340351  0.852193
# 19       12                    78.114  1.000000  0.218962  0.278943  0.916667
# 20       14                    58.124  0.863121  0.377512  0.226698  1.750000
# 21       20                   116.160  1.295462  0.379102  0.299742  1.505950
# 22       14                    92.569  1.198117  0.400470  0.314685  1.330145
# 23       12                   112.559  1.325011  0.307685  0.369603  0.757488
# 24       18                    84.162  0.918296  0.207720  0.220219  1.416667
# 25       15                    70.135  0.918296  0.208513  0.235045  1.400000
# 26        9                    42.081  0.918296  0.283731  0.289690  1.333333
# 27       28                   138.254  0.940286  0.453532  0.195593  1.303448
# 28       32                   142.286  0.896038  0.439397  0.179208  1.600000
# 29       16                    73.139  1.121641  0.445345  0.280410  1.729157
# 30       15                    74.123  1.158939  0.451644  0.296640  1.744077
# 31       10                    45.085  1.156780  0.491865  0.348225  1.921869
# 32        9                    46.069  1.224394  0.492298  0.386253  1.953000
# 33       14                    88.106  1.378783  0.288467  0.362137  1.429670
# 34       21                   102.177  1.115520  0.491427  0.253971  1.667047
# 35        8                    30.070  0.811278  0.296957  0.270426  2.000000
# 36       14                    88.106  1.378783  0.450128  0.362137  1.512289
# 37        9                    46.069  1.224394  0.392842  0.386253  1.710703
# 38       10                    45.085  1.156780  0.478884  0.348225  1.730467
#
#     Wiener    Z1
# 0       84  42.0
# 1       10  10.0
# 2       20  14.0
# 3       46  26.0
# 4       74  30.0
# 5      484  60.0
# 6       10  10.0
# 7       52  24.0
# 8       79  28.0
# 9       32  20.0
# 10      76  28.0
# 11       4   6.0
# 12       9  12.0
# 13       9  12.0
# 14       1   2.0
# 15      10  10.0
# 16      10  10.0
# 17      10  10.0
# 18      42  30.0
# 19      27  24.0
# 20      10  10.0
# 21      79  28.0
# 22      20  14.0
# 23      42  30.0
# 24      27  24.0
# 25      15  20.0
# 26       3  12.0
# 27     109  50.0
# 28     165  34.0
# 29      20  14.0
# 30      20  14.0
# 31       4   6.0
# 32       4   6.0
# 33      27  24.0
# 34      48  26.0
# 35       1   2.0
# 36      32  20.0
# 37       4   6.0
# 38       4   6.0

# %% [markdown]
# # Import molecular geometries from cartesian xyz coordinates

# %%
psi4_mols = []
for geo in xyzgeom_list:
    psi4mol = psi4.geometry(geo)
    psi4_mols.append(psi4mol)
    
E_list = []
wfn_list = []
homo_list = []
lumo_list = []
DM_list = []
const = psi4.constants.dipmom_au2debye #atomic units to Debye conversion factor for dipoles

# %% [markdown]
# # Molecular structure optimization round 2 + calculate HOMO, LUMO, and DM

# %%
psi4.set_options({'reference': 'uhf'})

k=0

for molec in psi4_mols: #iterate over list of molecular geometries
    
    E, wfn= psi4.optimize("B3LYP/6-31G*", molecule = molec,return_wfn=True) #returns energy and wavefunction of molecule
    
    E_list.append(E)
    wfn_list.append(wfn)
    
    HOMO = ( np.array(wfn.epsilon_a_subset("AO", "ALL")) )[wfn.nalpha()-1]
    LUMO = ( np.array(wfn.epsilon_a_subset("AO", "ALL")) )[wfn.nalpha()]
    dipole_xyz = wfn.variable("SCF DIPOLE")
    dipole_debye = np.linalg.norm(dipole_xyz) *const
  
    homo_list.append(HOMO)
    lumo_list.append(LUMO)
    DM_list.append(dipole_debye)
    
    k+=1
    strID = "fuel"+str(k)+ ".xyz"
    molec.save_xyz_file(strID,1) #write final optimized geometry to XYZ file
    print("Fuel "+str(k)+" done, "+ "k: "+str(k))
# Out:
# Optimizer: Optimization complete!
# Fuel 1 done, k: 1
# Optimizer: Optimization complete!
# Fuel 2 done, k: 2
# Optimizer: Optimization complete!
# Fuel 3 done, k: 3
# Optimizer: Optimization complete!
# Fuel 4 done, k: 4
# Optimizer: Optimization complete!
# Fuel 5 done, k: 5
# Optimizer: Optimization complete!
# Fuel 6 done, k: 6
# Optimizer: Optimization complete!
# Fuel 7 done, k: 7
# Optimizer: Optimization complete!
# Fuel 8 done, k: 8
# Optimizer: Optimization complete!
# Fuel 9 done, k: 9
# Optimizer: Optimization complete!
# Fuel 10 done, k: 10
# Optimizer: Optimization complete!
# Fuel 11 done, k: 11
# Optimizer: Optimization complete!
# Fuel 12 done, k: 12
# Optimizer: Optimization complete!
# Fuel 13 done, k: 13
# Optimizer: Optimization complete!
# Fuel 14 done, k: 14
# Optimizer: Optimization complete!
# Fuel 15 done, k: 15
# Optimizer: Optimization complete!
# Fuel 16 done, k: 16
# Optimizer: Optimization complete!
# Fuel 17 done, k: 17
# Optimizer: Optimization complete!
# Fuel 18 done, k: 18
# Optimizer: Optimization complete!
# Fuel 19 done, k: 19
# Optimizer: Optimization complete!
# Fuel 20 done, k: 20
# Optimizer: Optimization complete!
# Fuel 21 done, k: 21
# Optimizer: Optimization complete!
# Fuel 22 done, k: 22
# Optimizer: Optimization complete!
# Fuel 23 done, k: 23
# Optimizer: Optimization complete!
# Fuel 24 done, k: 24
# Optimizer: Optimization complete!
# Fuel 25 done, k: 25
# Optimizer: Optimization complete!
# Fuel 26 done, k: 26
# Optimizer: Optimization complete!
# Fuel 27 done, k: 27
# Optimizer: Optimization complete!
# Fuel 28 done, k: 28
# Optimizer: Optimization complete!
# Fuel 29 done, k: 29
# Optimizer: Optimization complete!
# Fuel 30 done, k: 30
# Optimizer: Optimization complete!
# Fuel 31 done, k: 31
# Optimizer: Optimization complete!
# Fuel 32 done, k: 32
# Optimizer: Optimization complete!
# Fuel 33 done, k: 33
# Optimizer: Optimization complete!
# Fuel 34 done, k: 34
# Optimizer: Optimization complete!
# Fuel 35 done, k: 35
# Optimizer: Optimization complete!
# Fuel 36 done, k: 36
# Optimizer: Optimization complete!
# Fuel 37 done, k: 37
# Optimizer: Optimization complete!
# Fuel 38 done, k: 38
# Optimizer: Optimization complete!
# Fuel 39 done, k: 39

# %% [markdown]
# # Add HOMO, LUMO, DM lists to dataframe and save as CSV file

# %%
df2 = pd.DataFrame(list(zip(homo_list,lumo_list,DM_list)), columns=['HOMO','LUMO','DM'])
df2
# Out:
#         HOMO      LUMO            DM
# 0  -0.227243  0.009793  3.760093e-02
# 1  -0.249853  0.025890  3.367899e-01
# 2  -0.249613  0.025174  3.287650e-01
# 3  -0.296727  0.086465  5.600970e-02
# 4  -0.299486  0.081422  7.813802e-02
# 5  -0.286436  0.079358  1.693138e-01
# 6  -0.234996  0.036312  1.167217e-06
# 7  -0.242486 -0.009403  2.647785e+00
# 8  -0.294644  0.076233  6.105559e-02
# 9  -0.240036 -0.011356  2.704513e+00
# 10 -0.297783  0.089524  9.507884e-02
# 11 -0.255219 -0.021804  2.641111e+00
# 12 -0.275350  0.009831  1.580750e+00
# 13 -0.244184 -0.011171  2.816258e+00
# 14 -0.281924  0.052429  4.481826e-07
# 15 -0.257122 -0.065010  3.160941e+00
# 16 -0.289217 -0.056326  3.882789e+00
# 17 -0.259567  0.006832  1.589377e+00
# 18 -0.198176  0.009195  1.712630e+00
# 19 -0.246254  0.003570  6.182948e-06
# 20 -0.317547  0.094901  1.674712e-07
# 21 -0.268424  0.016464  1.807736e+00
# 22 -0.288326  0.024923  2.466321e+00
# 23 -0.246407 -0.012525  1.929411e+00
# 24 -0.291958  0.087753  1.454744e-08
# 25 -0.309194  0.085469  6.358411e-03
# 26 -0.287641  0.105454  4.021792e-05
# 27 -0.274152  0.084698  2.572506e-02
# 28 -0.293026  0.090717  5.363615e-02
# 29 -0.210736  0.086620  9.542977e-01
# 30 -0.246650  0.092755  1.154649e+00
# 31 -0.215171  0.086745  1.029260e+00
# 32 -0.251762  0.092336  1.274376e+00
# 33 -0.243687  0.087365  1.150275e-03
# 34 -0.241370  0.081553  1.101943e+00
# 35 -0.340119  0.104782  7.301728e-08
# 36 -0.267933  0.015669  1.767134e+00
# 37 -0.263035  0.075791  1.674106e+00
# 38 -0.228905  0.083387  1.397365e+00

# %%
df3 = pd.concat([df,df2], axis=1)
df3

# %%
df3.to_csv('FuelDescriptors1.csv', encoding='utf-8', index=False)
